# %% [markdown]
# ## New date
# ### new wafer
# - Nb28/Niw60s for Tc measurements. New Nb target, bulk Tc = 8.6 K.
# - Thermometer read with KT2001 multimeter at 200 kOhm range.
# - Bias: 10 mV ac over 100 kOhm resistor, 83 Hz, 300 ms tc
# - Input: 1 kOhm - 10 nF LPF, ac float, low noise, max filtering.

# %% [markdown]
# ## Process new datafiles

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport nb_cmds, mylib

import glob

datafiles = glob.glob("data/*.zip")
ignore    = glob.glob("data/RSJ_*") + glob.glob("data/004*")
nb_cmds.process_new_datafiles(datafiles, ignore)
# Out:
# N of datafiles: 12
# Datafile: data/001_VItrace-HI_B160617_chip23_A01_3500OeP.zip
# /home/burm/vboxsf/work/nonpublic/software/src/cryomem-0.2.0/cryomem/common/metadata.py:44: UnsafeLoaderWarning:
# The default 'Loader' for 'load(stream)' without further arguments can be unsafe.
# Use 'load(stream, Loader=ruamel_yaml.Loader)' explicitly if that is OK.
# Alternatively include the following in your code:
#
#   import warnings
#   warnings.simplefilter('ignore', ruamel_yaml.error.UnsafeLoaderWarning)
#
# In most other cases you should consider using 'safe_load(stream)'
#   rawconfig = yaml.load(src)
# Default updateguess = 0.8
# Quick guess: [0.000788, -0.000788, 0.015112230729906261, 2.0329218106995884e-06]
# /home/burm/vboxsf/work/nonpublic/software/src/cryomem-0.2.0/cryomem/common/plothyst.py:89: MatplotlibDeprecationWarning: The set_color_cycle function was deprecated in version 1.5. Use `.set_prop_cycle` instead.
#   ax.set_color_cycle(None)        # windows bug?
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? r
# Fit guess for istart (enter to skip)?
# No manual input for istart.
# Fit guess for iend (enter to skip)? 40
# Fit guess for Icp0 (enter to skip)?
# No manual input for Icp0.
# Fit guess for Hcen0 (enter to skip)?
# No manual input for Hcen0.
# Fit guess for Hnod0 (enter to skip)?
# No manual input for Hnod0.
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Datafile: data/002_VItrace-HIpulse_B160617_chip23_A01.zip
# Default updateguess = 0.8
# Quick guess: [0.0033490000000000004, -0.0033490000000000004, 0.01890376681816684, 2.0000000000000003e-06]
# Your choice (c: continue, d: discard, r: refit, q: quit)? d
# Datafile: data/003_VItrace-HIpulse_B160617_chip23_A01.zip
# Default updateguess = 0.8
# Quick guess: [0.0033490000000000004, -0.0033490000000000004, 0.01874144844993533, 2e-06]
# Your choice (c: continue, d: discard, r: refit, q: quit)? d
# Datafile: data/005_VItrace-HI_B160617_chip23_A10_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.0009456, -0.0009456, 0.0018837720248569925, -1.4892988929889301e-06]
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Datafile: data/006_VItrace-HIpulse_B160617_chip23_A10.zip
# Default updateguess = 0.8
# Quick guess: [0.0026792, -0.0026792, 0.0020128672306078273, -1.008058608058608e-06]
# Your choice (c: continue, d: discard, r: refit, q: quit)? d
# Datafile: data/007_VItrace-HI_B160617_chip23_A11_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.0011032, -0.0011032, 0.0009329404668377835, -5.087591240875912e-07]
# Fit not good. Index: 2, Trial: 1
# Fit not good. Index: 2, Trial: 2
# Fit not good. Index: 88, Trial: 1
# Fit not good. Index: 88, Trial: 2
# Your choice (c: continue, d: discard, r: refit, q: quit)? d
# Datafile: data/008_VItrace-HI_B160617_chip23_A12_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.0013396, -0.0013396, 0.0006120570014947173, -1.0457627118644066e-06]
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Datafile: data/009_VItrace-HI_B160617_chip23_A01_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.000788, -0.000788, 0.01506433531343738, -6.642066420664288e-08]
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Datafile: data/010_VItrace-HI_B160617_chip23_A02_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.002758, -0.002758, 0.15124923205983082, -3.126436781609195e-06]
# Fit not good. Index: 4, Trial: 1
# Fit not good. Index: 4, Trial: 2
# Fit not good. Index: 4, Trial: 3
# Fit not good. Index: 4, Trial: 4
# Fit not good. Index: 4, Trial: 5
# Fit not good. Index: 5, Trial: 1
# Fit not good. Index: 5, Trial: 2
# Fit not good. Index: 5, Trial: 3
# Fit not good. Index: 5, Trial: 4
# Fit not good. Index: 5, Trial: 5
# Your choice (c: continue, d: discard, r: refit, q: quit)? d
# Datafile: data/011_VItrace-HI_B160617_chip23_A07_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.0011032, -0.0011032, 0.007075530822326023, 1.6996336996336992e-07]
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Datafile: data/012_VItrace-HI_B160617_chip23_A08_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.0012608, -0.0012608, 0.006271785878601674, -3.582089552238808e-07]
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Datafile: data/013_VItrace-HI_B160617_chip23_A09_4000OeP.zip
# Default updateguess = 0.8
# Quick guess: [0.0009456, -0.0009456, 0.005378592926810199, -1.5443223443223442e-06]
# Fit not good. Index: 9, Trial: 1
# Fit not good. Index: 9, Trial: 2
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Your choice (c: continue, d: discard, r: refit, q: quit)? c
# Done.

# %% [markdown]
# ## Show all Ic(B)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport nb_cmds, mylib

nb_cmds.show_BIc()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded existing db: results.txt
# /home/burm/vboxsf/work/nonpublic/software/src/cryomem-0.2.0/cryomem/common/metadata.py:44: UnsafeLoaderWarning:
# The default 'Loader' for 'load(stream)' without further arguments can be unsafe.
# Use 'load(stream, Loader=ruamel_yaml.Loader)' explicitly if that is OK.
# Alternatively include the following in your code:
#
#   import warnings
#   warnings.simplefilter('ignore', ruamel_yaml.error.UnsafeLoaderWarning)
#
# In most other cases you should consider using 'safe_load(stream)'
#   rawconfig = yaml.load(src)
# /home/burm/vboxsf/work/nonpublic/software/src/cryomem-0.2.0/cryomem/common/plothyst.py:89: MatplotlibDeprecationWarning: The set_color_cycle function was deprecated in version 1.5. Use `.set_prop_cycle` instead.
#   ax.set_color_cycle(None)        # windows bug?

# %% [markdown]
# ## Thickness dependence

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport nb_cmds, mylib

devspecs = [{"wafer":"B160617", "cols": ["2","3","4"], 'xoffset': 0, 'duration': 29, 'calfile': "wedge_Ni_B160224b.dat",
            'reticle': 'SF1', 'angle': 0}]
nb_cmds.show_thickness_dependence(dbs=['results.txt'], devspecs=devspecs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded existing db: results.txt
# /home/burm/miniconda3-jessie/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# fitted thickness distribution
import cryomem.fab.wedge as wedge

w = wedge.Wedge()
for chip in ["36", "35", "34", "33", "32", "31", "41"]:
    kwargs = {'calfile': 'wedge_Ni_B180329.dat', 'reticle': 'SF1', 'chip': chip, 'device': "A10", 'angle': 0,
                 "duration": 60}
    d = w.get_thickness(**kwargs)
    print("Chip {}: {:.2f} nm".format(chip, d))
# Out:
# Chip 36: 1.10 nm
# Chip 35: 1.69 nm
# Chip 34: 2.81 nm
# Chip 33: 4.92 nm
# Chip 32: 8.44 nm
# Chip 31: 13.83 nm
# Chip 41: 17.20 nm

# %%
# plot wedge rate calibration
#%matplotlib notebook
import cryomem.fab.wedge as wedge
import matplotlib.pyplot as plt
w = wedge.Wedge()
w.plot(calfile='wedge_Ni_B180329.dat', ncontour=20)
#plt.savefig("wedge.png")
# Out:
# 0
